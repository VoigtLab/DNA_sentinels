# %%
import pandas as pd

# %%
fits_final=pd.read_csv('fits_fig5b.csv')
fits_final['fa_mean']=fits_final[['fa1', 'fa2', 'fa3', 'fa4']].mean(axis=1)
fits_final

#579= Bs SEN5:1 - DNA
#579_A1 = Bs SEN5:1 + SEQ1 (8nM)
#579_F1 = Bs SEN5:1 + SEQ5 (8nM)
#579_AF1 = Bs SEN5:1 + SEQ1 (8nM) + SEQ5 (8nM)
#579_A2 = Bs SEN5:1 + SEQ1 (800pM)
#579_F2 = Bs SEN5:1 + SEQ5 (800pM)
#579_AF2 = Bs SEN5:1 + SEQ1 (800pM) + SEQ5 (800pM)
# Out:
#     sample    r1_mu1     r1_s1        r1_A1    r1_mu2     r1_s2       r1_A2  \
# 0      579  5.323131  0.524374  17391.99980  8.244949  0.215776    0.940462
# 1   579_A1       NaN       NaN          NaN       NaN       NaN         NaN
# 2   579_F1       NaN       NaN          NaN       NaN       NaN         NaN
# 3  579_AF1       NaN       NaN          NaN       NaN       NaN         NaN
# 4   579_A2  5.332730  0.513043  17639.07905  8.264936  0.379465    2.910044
# 5   579_F2  5.262857  0.518656  17412.89264  8.219493  0.392502    3.255327
# 6  579_AF2  5.288698  0.524055  11854.61090  7.338556  0.516504  315.999762
#
#       fneg1        A1+A2         Aneg    ...           r4_A1    r4_mu2  \
# 0  0.129113  17392.94026  2578.588324    ...     17355.98401  7.611140
# 1  0.122788          NaN          NaN    ...     17706.97798  9.538116
# 2  0.164640          NaN          NaN    ...     17248.33263  8.239154
# 3  0.170643          NaN          NaN    ...     17126.29281  7.496148
# ...
